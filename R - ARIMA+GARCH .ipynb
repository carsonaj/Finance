# %%
library("httr")
library("jsonlite")

library(ggplot2)

library(tseries)
library(forecast)
library(rugarch)

# %%
#publishable 
api_key <- "pk_06ea5c94527b4754a9196efb576df932"
url <- "https://cloud.iexapis.com/v1/"
ticker <- "IETC"
endpoint <- paste("/stock/", ticker, "/chart/1y", "?token=", api_key, sep="")
url <- paste(url, endpoint, sep="")

length <- 200
query <- list(chartLast=length) 

request <- GET(url, query=query)
response <- content(request, as="text")
df <- fromJSON(response, flatten = TRUE) 
price <- df[c("date", "close")]
write.csv(price, "/home/carson/Desktop/price.csv", row.names=FALSE)

s <- ts(log(price$close))
ds <- diff(s)

# %%
tsdisplay(ds)
# Out:
# Plot with title “”
# Plot with title “”

# %%
fit <- auto.arima(s, seasonal=FALSE)
fit
# Out:
# Series: s
# ARIMA(0,1,0)
#
# sigma^2 estimated as 0.0002187:  log likelihood=556.24
# AIC=-1110.47   AICc=-1110.45   BIC=-1107.18

# %%
fit <- auto.arima(ds, seasonal=FALSE)
fit
# Out:
# Series: ds
# ARIMA(0,0,0) with zero mean
#
# sigma^2 estimated as 0.0002186:  log likelihood=556.24
# AIC=-1110.47   AICc=-1110.45   BIC=-1107.18

# %%
tsdisplay(residuals(fit, standardize=TRUE))
tsdisplay(residuals(fit, standardize=TRUE)^2)
# Out:
# Plot with title “”
# Plot with title “”

# %%
garchSpec <- ugarchspec(variance.model=list(model="sGARCH",
                               garchOrder=c(2,2)),
           mean.model=list(armaOrder=c(0,0)), 
           distribution.model="std")

garchFit <- ugarchfit(spec=garchSpec, data=ds)

# %%
garchFit
# Out:
# *---------------------------------*
# *          GARCH Model Fit        *
# *---------------------------------*
#
# Conditional Variance Dynamics
# -----------------------------------
# GARCH Model	: sGARCH(2,2)
# Mean Model	: ARFIMA(0,0,0)
# Distribution	: std
#
# Optimal Parameters
# ------------------------------------
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.001322    0.000685 1.930482 0.053547
# omega   0.000010    0.000009 1.145520 0.251994
# alpha1  0.090194    0.069084 1.305578 0.191696
# alpha2  0.280453    0.100644 2.786589 0.005327
# beta1   0.000019    0.104590 0.000182 0.999855
# beta2   0.628333    0.108617 5.784854 0.000000
# shape   4.604648    1.887538 2.439500 0.014708
#
# Robust Standard Errors:
#         Estimate  Std. Error  t value Pr(>|t|)
# mu      0.001322    0.000823 1.606545 0.108154
# omega   0.000010    0.000010 1.064136 0.287267
# alpha1  0.090194    0.062479 1.443593 0.148853
# alpha2  0.280453    0.093540 2.998229 0.002716
# beta1   0.000019    0.061746 0.000308 0.999754
# beta2   0.628333    0.078200 8.034947 0.000000
# shape   4.604648    2.172303 2.119708 0.034031
#
# LogLikelihood : 591.2937
#
# Information Criteria
# ------------------------------------
#
# Akaike       -5.8723
# Bayes        -5.7565
# Shibata      -5.8747
# Hannan-Quinn -5.8254
#
# Weighted Ljung-Box Test on Standardized Residuals
# ------------------------------------
#                         statistic p-value
# Lag[1]                     0.1137  0.7359
# Lag[2*(p+q)+(p+q)-1][2]    0.2034  0.8521
# Lag[4*(p+q)+(p+q)-1][5]    0.6309  0.9357
# d.o.f=0
# H0 : No serial correlation
#
# Weighted Ljung-Box Test on Standardized Squared Residuals
# ------------------------------------
#                          statistic p-value
# Lag[1]                   0.0009514  0.9754
# Lag[2*(p+q)+(p+q)-1][11] 3.8584357  0.7538
# Lag[4*(p+q)+(p+q)-1][19] 5.7884426  0.8899
# d.o.f=4
#
# Weighted ARCH LM Tests
# ------------------------------------
#             Statistic Shape Scale P-Value
# ARCH Lag[5]    0.4669 0.500 2.000  0.4944
# ARCH Lag[7]    1.2685 1.473 1.746  0.6835
# ARCH Lag[9]    1.3666 2.402 1.619  0.8751
#
# Nyblom stability test
# ------------------------------------
# Joint Statistic:  1.1602
# Individual Statistics:
# mu     0.21293
# omega  0.08898
# alpha1 0.17645
# alpha2 0.35114
# beta1  0.21760
# beta2  0.22944
# shape  0.17924
#
# Asymptotic Critical Values (10% 5% 1%)
# Joint Statistic:     	 1.69 1.9 2.35
# Individual Statistic:	 0.35 0.47 0.75
#
# Sign Bias Test
# ------------------------------------
#                    t-value   prob sig
# Sign Bias           0.5383 0.5910
# Negative Sign Bias  0.1681 0.8667
# Positive Sign Bias  0.8065 0.4210
# Joint Effect        2.5728 0.4623
#
#
# Adjusted Pearson Goodness-of-Fit Test:
# ------------------------------------
#   group statistic p-value(g-1)
# 1    20     25.62       0.1410
# 2    30     30.30       0.3993
# 3    40     40.80       0.3913
# 4    50     50.50       0.4141
#
#
# Elapsed time : 0.574028

# %%
res <- residuals(garchFit, standardize=TRUE)

# %%
tsdisplay(res^2)
# Out:
# Plot with title “”

# %%
hhat <- ts(garchFit@fit$sigma^2)
plot.ts(hhat)
# Out:
# plot without title

# %%
ndf <- read.csv("http://download.macrotrends.net/assets/php/stock_data_export.php?t=AAPL", skip=14)
ndf$date <- as.Date(ndf$date)
head(ndf)
# Out:
#   date       open   high   low    close  volume
# 1 1980-12-12 0.5134 0.5155 0.5134 0.5134 117258400
# 2 1980-12-15 0.4889 0.4889 0.4866 0.4866  43971200
# 3 1980-12-16 0.4530 0.4530 0.4509 0.4509  26432000
# 4 1980-12-17 0.4620 0.4643 0.4620 0.4620  21610400
# 5 1980-12-18 0.4755 0.4777 0.4755 0.4755  18362400
# 6 1980-12-19 0.5045 0.5068 0.5045 0.5045  12157600

# %%
price <- ndf[c("date", "close")]
price <- subset(price, date > "1995-01-01")
head(price)
# Out:
#      date       close
# 3553 1995-01-03 1.3707
# 3554 1995-01-04 1.4064
# 3555 1995-01-05 1.3886
# 3556 1995-01-06 1.5000
# 3557 1995-01-09 1.4714
# 3558 1995-01-10 1.5604

# %%
x <- log(price$close)

# %%
dx <- diff(x)
length(dx)
# Out:
# [1] 6142

# %%
tsdisplay(dx)
# Out:
# Plot with title “”

# %%
fit <- auto.arima(dx, seasonal=FALSE)
fit
tsdisplay(residuals(fit, standardize=TRUE)^2)
# Out:
# Series: dx
# ARIMA(0,0,1) with non-zero mean
#
# Coefficients:
#           ma1   mean
#       -0.0190  8e-04
# s.e.   0.0128  4e-04
#
# sigma^2 estimated as 0.0008161:  log likelihood=13123.59
# AIC=-26241.18   AICc=-26241.18   BIC=-26221.01
# Plot with title “”

# %%
garchSpec <- ugarchspec(variance.model=list(model="sGARCH",
                               garchOrder=c(2,2)),
           mean.model=list(armaOrder=c(0,1)), 
           distribution.model="std")

garchFit <- ugarchfit(spec=garchSpec, data=dx)

# %%
tsdisplay(residuals(garchFit, standardize=TRUE)^2)
# Out:
# Plot with title “”

# %%
model <- ugarchforecast(garchFit, n.ahead=10)

# %%
model
# Out:
# *------------------------------------*
# *       GARCH Model Forecast         *
# *------------------------------------*
# Model: sGARCH
# Horizon: 10
# Roll Steps: 0
# Out of Sample: 0
#
# 0-roll forecast [T0=1986-10-25 19:00:00]:
#        Series   Sigma
# T+1  0.001157 0.01931
# T+2  0.001121 0.01949
# T+3  0.001121 0.01944
# T+4  0.001121 0.01950
# T+5  0.001121 0.01951
# T+6  0.001121 0.01955
# T+7  0.001121 0.01957
# T+8  0.001121 0.01960
# T+9  0.001121 0.01962
# T+10 0.001121 0.01965

# %%
plot.ts(model@forecast, which="all")
# Out:
# Error in xy.coords(x, NULL, log = log, setLab = FALSE): (list) object cannot be coerced to type 'double'
# Traceback:
#
# 1. plot.ts(model@forecast, which = "all")
# 2. plotts(x = x, y = y, plot.type = plot.type, xy.labels = xy.labels,
#  .     xy.lines = xy.lines, panel = panel, nc = nc, xlabel = xlabel,
#  .     ylabel = ylabel, axes = axes, ...)
# 3. xy.coords(x, NULL, log = log, setLab = FALSE)

# %%
help(plot, pack=rugarch)
